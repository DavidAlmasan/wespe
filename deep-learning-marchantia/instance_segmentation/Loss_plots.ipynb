# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
losses = np.load('marchantia_results/insseg/16fdim_1000_session2/unet16_1000epochs_16fdim.npy')
losses2 = np.load('marchantia_results/insseg/frozen_encoder/unet16_1000epochs_16fdim_freezeenc.npy')
# losses3 = np.load('marchantia_results/insseg/unet16_300epochs_32fdim.npy')

# %%
plt.plot(losses[0:970])
plt.plot(losses2[0:970])
# plt.plot(losses3)
plt.xlabel('epoch')
plt.ylabel('discriminative loss')
plt.yscale('log')
plt.legend(['all layers trainable','encoder layers frozen'])
plt.savefig('loss_plot.png', dpi = 150)

# %%
losses_sem = np.load('marchantia_results/semseg/gray_variation/unet16_100epochs_255grayvar.npy')
losses_sem2 = np.load('marchantia_results/semseg/100epochs_16fdim_2/unet16_100epochs.npy')


plt.plot(losses_sem)
plt.plot(losses_sem2)
plt.xlabel('epoch')
plt.ylabel('loss')
# plt.yscale('log')
# Out:
# Text(0, 0.5, 'loss')
